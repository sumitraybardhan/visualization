# %% [markdown]
# January 22 2026

# %% [markdown]
# I am adding coding comments from the data visualization I chose from session 1 here

# %%
import seaborn as sns
import matplotlib.pyplot as plt
df = sns.load_dataset('iris')

# use the function scatterplot() to make a scatterplot
sns.scatterplot(x=df["sepal_length"], y=df["sepal_width"])





sns.scatterplot(
    data=df,
    x="sepal_length",
    y="sepal_width",
    hue="species",    # Add color based on species  
    style="species"   # Add different markers based on species
) # Add legend based on species
# Overall allows better visual distinction between species and grouping


plt.title("Sepal Length vs Width by Iris Species")
plt.xlabel("Sepal Length (cm)")
plt.ylabel("Sepal Width (cm)")
plt.tight_layout()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests

np.random.seed(613)
x=np.arange(50)
y1 = np.random.randint(0,100,50)
y2 = np.random.randint(0,100,50)

fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y1, label='Person 1')
ax.plot(x,y2, label='Person 2')
ax.legend(loc ='upper right', frameon=True) # Attempting different placement of legend
fig.show()
# Out:
# /var/folders/wj/x4hyhm350ls6dzw_sxgnhg440000gn/T/ipykernel_12062/1338146544.py:17: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y1, label='Person 1')
ax.plot(x,y2, label='Person 2')
ax.legend(loc ='upper right', frameon=False) # Attempting different placement of legend
fig.show()
# Out:
# /var/folders/wj/x4hyhm350ls6dzw_sxgnhg440000gn/T/ipykernel_12062/2147054506.py:5: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y1, label='Person 1')
ax.plot(x,y2, label='Person 2')
ax.legend(loc ='upper right', frameon=True, fontsize=12, ncol=2, shadow=True) # Attempting different placement of legend
fig.show()
# Out:
# /var/folders/wj/x4hyhm350ls6dzw_sxgnhg440000gn/T/ipykernel_12062/2716332342.py:5: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y1, label='Person 1')
ax.plot(x,y2, label='Person 2')
ax.legend(loc ='lower right', bbox_to_anchor=(1, 1))

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label='Person 1')
ax.scatter(x,y2, label='Person 2')
ax.legend(loc ='lower right')

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label='Person 1')
ax.scatter(x,y2, label='Person 2')
ax.legend(loc ='lower right')

ax.text (10, 95, "This is critical value")
# Out:
# Text(10, 95, 'This is critical value')

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label='Person 1')
ax.scatter(x,y2, label='Person 2')
ax.legend(loc ='lower right')

ax.text (10, 95, "This is critical value", ha ='center', color ='red', fontsize=12)
# Out:
# Text(10, 95, 'This is critical value')

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label='Person 1')
ax.scatter(x,y2, label='Person 2')
ax.legend(loc ='lower right', prop={"family":"serif", "size": 10})

ax.text (10, 95, "This is critical value", ha ='center', color ='red', fontsize=12)
# Out:
# Text(10, 95, 'This is critical value')

# %%
fig, ax = plt.subplots()
ax.axis([0, 10, 0, 10])
ax.text(1,5,". Data:(1,5)", transform=ax.transData)
# Out:
# Text(1, 5, '. Data:(1,5)')

# %%
fig, ax = plt.subplots()
ax.axis([0, 10, 0, 10])
ax.text(1,5,". Data:(1,5)", transform=ax.transData)
ax.text(0.5,0.1,". Axes:(0.5,0.1)", transform=ax.transAxes)
# Out:
# Text(0.5, 0.1, '. Axes:(0.5,0.1)')

# %%
fig, ax = plt.subplots()
ax.axis([0, 10, 0, 10])
ax.text(1,5,". Data:(1,5)", transform=ax.transData)
ax.text(0.5,0.1,". Axes:(0.5,0.1)", transform=ax.transAxes)
ax.text(0.5,0.1,". Figure:(0.5,0.1)", transform=fig.transFigure)
# Out:
# Text(0.5, 0.1, '. Figure:(0.5,0.1)')

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label='Person 1')
ax.scatter(x,y2, label='Person 2')
ax.legend(loc ='lower right')
ax.annotate('Critical Value', xy=(10, 95), xytext=(30, 94), arrowprops=dict(facecolor='black'))
# Out:
# Text(30, 94, 'Critical Value')

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label='Person 1')
ax.scatter(x,y2, label='Person 2')
ax.legend(loc ='lower right')

#ax.yaxis.set_major_locator(plt.NullLocator())
#ax.xaxis.set_major_locator(plt.NullLocator())
ax.xaxis.set_major_formatter(plt.NullFormatter())

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label='Person 1')
ax.scatter(x,y2, label='Person 2')
ax.legend(loc ='lower right')
ax.xaxis.set_major_locator(plt.MaxNLocator(10))

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label='Person 1')
ax.scatter(x,y2, label='Person 2')
ax.legend(loc ='lower right')
ax.xaxis.set_major_locator(plt.MultipleLocator(5))

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label='Person 1')
ax.scatter(x,y2, label='Person 2')
ax.legend(loc ='lower right')
plt.xticks(rotation=45, ha='right')
# Out:
# (array([-10.,   0.,  10.,  20.,  30.,  40.,  50.,  60.]),
#  [Text(-10.0, 0, '−10'),
#   Text(0.0, 0, '0'),
#   Text(10.0, 0, '10'),
#   Text(20.0, 0, '20'),
#   Text(30.0, 0, '30'),
#   Text(40.0, 0, '40'),
#   Text(50.0, 0, '50'),
#   Text(60.0, 0, '60')])

# %% [markdown]
# January 27 2026 Part II

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label='Person 1')
ax.scatter(x,y2, label='Person 2')
ax.legend(loc ='lower right')
plt.xticks(rotation=45, ha='right')
font1={'family':'serif','color':'blue'}
ax.set_xlabel("New X axis", fontsize=14, fontdict=font1)
# Out:
# Text(0.5, 0, 'New X axis')

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label='Person 1')
ax.scatter(x,y2, label='Person 2')
ax.legend(loc ='lower right')
plt.xticks(rotation=45, ha='right')
font1={'family':'serif','color':'blue'}
plt.xlabel("New X axis", fontsize=14, fontdict=font1)
# Out:
# Text(0.5, 0, 'New X axis')

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('fivethirtyeight')  

np.random.seed(613)
x = np.arange(50)
y1 = np.random.randint(0, 100,50)
y2 = np.random.randint(0, 100,50)
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y1)
ax.plot(x,y2)
fig.show()
# Out:
# /var/folders/wj/x4hyhm350ls6dzw_sxgnhg440000gn/T/ipykernel_12062/1558324804.py:10: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
