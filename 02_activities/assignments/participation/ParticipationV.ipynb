# %% [markdown]
# January 29 2026

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests

from PIL import Image
import requests
from io import BytesIO
url = "https://upload.wikimedia.org/wikipedia/en/c/cb/Monkey_D_Luffy.png"
headers = {
    "User-Agent": "Mozilla/5.0",
    "Accept": "image/*,*/*;q=0.8",
    "Referer": "https://en.wikipedia.org/"
}

url = "https://upload.wikimedia.org/wikipedia/en/c/cb/Monkey_D_Luffy.png"
headers = {
    "User-Agent": "Mozilla/5.0",
    "Accept": "image/*,*/*;q=0.8",
    "Referer": "https://en.wikipedia.org/"
}

response=requests.get(url,headers=headers)
image_file=BytesIO(response.content)
image=Image.open(image_file)
image

x=np.array(['Luffy','Zoro','Nami','Usopp','Sanji'])
y1=np.array([110,180,240,99,220])
y2=np.array([170,100,90,120,50])
fig,ax=plt.subplots(figsize=(7,3))
ax.plot(x,y2,color='red')
ax_image=fig.add_axes([0.1,0.11,0.15,0.35])
ax_image.imshow(image)
ax_image.axis('off')
plt.savefig("/Users/sumitraybardhan/Downloads/fig1a.png",
            dpi=300,
            bbox_inches="tight")

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests

# %%
tips = sns.load_dataset('tips')
print(tips)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.lineplot(data=tips, x='total_bill', y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.set_style('darkgrid')
sns.lineplot(data=tips, x='total_bill', y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.set_style('darkgrid')
tipgraph =sns.lineplot(data=tips, x='total_bill', y='tip')
tipgraph.set(title = 'Tips vs Total Bill', xlabel = 'Total Bill ($)', 
             ylabel = 'Tip amount($)')
# Out:
# [Text(0.5, 1.0, 'Tips vs Total Bill'),
#  Text(0.5, 0, 'Total Bill ($)'),
#  Text(0, 0.5, 'Tip amount($)')]

# %%
sns.set_style('darkgrid')
tipgraph =sns.lineplot(data=tips, x='total_bill', y='tip',
                       color='hotpink', marker='o', markerfacecolor='blue',
                       linestyle='--', linewidth=2)
tipgraph.set(title = 'Tips vs Total Bill', xlabel = 'Total Bill ($)', 
             ylabel = 'Tip amount($)')
# Out:
# [Text(0.5, 1.0, 'Tips vs Total Bill'),
#  Text(0.5, 0, 'Total Bill ($)'),
#  Text(0, 0.5, 'Tip amount($)')]

# %%
tipgraph= sns.scatterplot(data=tips, x='total_bill', y='tip')

# %%
tipgraph= sns.scatterplot(data=tips, x='total_bill', y='tip', style='time',
                          hue='day')
tipgraph.set(title = 'Tips vs Total Bill', xlabel = 'Total Bill ($)', 
             ylabel = 'Tip amount($)')
# Out:
# [Text(0.5, 1.0, 'Tips vs Total Bill'),
#  Text(0.5, 0, 'Total Bill ($)'),
#  Text(0, 0.5, 'Tip amount($)')]

# %%
aph= sns.scatterplot(data=tips, x='total_bill', y='tip', style='time',
                          hue='day',
                          palette=['orange','green','blue','red']) 
                          
aph.set(title = 'Tips vs Total Bill', xlabel = 'Total Bill ($)', 
             ylabel = 'Tip amount($)')
# Out:
# [Text(0.5, 1.0, 'Tips vs Total Bill'),
#  Text(0.5, 0, 'Total Bill ($)'),
#  Text(0, 0.5, 'Tip amount($)')]

# %%
sns.pairplot(data=tips)

# %%
sns.pairplot(data=tips, hue= 'day')

# %%
daysplot = sns.relplot(data=tips, x='total_bill', y='tip', col='day',
                       hue='sex', kind='scatter', col_wrap=2)

# %%
daysplot = sns.relplot(data=tips, x='total_bill', y='tip', col='day',
                       hue='sex', kind='scatter', col_wrap=2)

# %%
import plotly.graph_objects as go

# %%
x1= np.array(["Luffy","Zoro","Nami","Usopp","Sanji"])
y1= np.array([110,180,240,99,220])

# %%
graph = go.Figure()

# %%
graph.add_trace(go.Bar(x=x1, y=y1, marker_color='indianred'))

# %%
graph = go.Figure()
graph.add_trace(go.Bar(x=x1, y=y1, marker_color='indianred'))
graph.update_layout(title_text='One Piece Character Scores',
                  xaxis_title='Pirates',
                  yaxis_title='Score')

# %%
graph = go.Figure()
graph.add_trace(go.Bar(x=x1, y=y1, marker_color='indianred'))
graph.update_layout(title_text='One Piece Character Scores',
                  xaxis_title='Pirates',
                  yaxis_title='Score')
#graph.write_html('one_piece_characters.html')

# %%
graph = go.Figure()
graph.add_trace(go.Scatter(x=x1, y=y1, mode='markers',
                           marker=dict(
                                 size=12,
                                 color='LightSkyBlue',
                                 opacity=1,
                                 line=dict(
                                      width=2,
                                      color='DarkSlateGrey'
                                 )
                           )))
graph.update_layout(title_text='One Piece Character Scores',
                  xaxis_title='Pirates',
                  yaxis_title='Score',
                  width=500, height=500)

# %%
from wordcloud import WordCloud
df = pd.read_csv("https://raw.githubusercontent.com/prasertcbs/basic-dataset/master/movie_quotes.csv",
on_bad_lines='skip')
df
# Out:
#                                                  quote  \
# 0                      Do, or do not. There is no try.
# 1    Listen to them. Children of the night. What mu...
# 2                              It's alive! It's alive!
# 3    Oh, no, it wasn't the airplanes. It was Beauty...
# 4    Magic Mirror on the wall, who is the fairest o...
# ..                                                 ...
# 727  I didn't know if you were lost. Stick with me....
# 728  This guy's awesome! He's holding his own while...
# 729     Murder is murder, it don’t matter who you are.
# 730  You know what a lion is? A lion is a strong an...
# 731  That was the best acting i've ever seen in my ...
#
#                                               movie   type  year
# 0    Star Wars: Episode V - The Empire Strikes Back  movie  1890
# 1                                           Dracula  movie  1931
# 2                                      Frankenstein  movie  1931
# ...

# %%
text=" ".join(each for each in df.quote)
wordcloud = WordCloud(background_color='white', 
                      colormap='inferno').generate(text)

fig,ax=plt.subplots(figsize=(7,3))
ax.imshow(wordcloud, interpolation='bilinear')
ax.axis('off')
# Out:
# (np.float64(-0.5), np.float64(399.5), np.float64(199.5), np.float64(-0.5))

# %%
from matplotlib_venn import venn2, venn2_circles, venn2_unweighted

# %%
A = set(["apple", "banana", "watermelon"])
B = set(["pumpkin", "blueberry", "apple", "key lime"])

diagram= venn2_unweighted([A, B], set_labels = ('Fruits', 'Pies'),
                          set_colors=('blue', 'red'),
                            alpha = 0.7)

# %%
diagram= venn2_unweighted([A, B], set_labels = ('Fruits', 'Pies'),
                          set_colors=('blue', 'red'),
                            alpha = 0.7)

diagram.get_label_by_id("10").set_text("\n".join(A - B))
diagram.get_label_by_id("11").set_text("\n".join(A & B))
diagram.get_label_by_id("01").set_text("\n".join(B - A))
